# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-расчета-эффективности" data-toc-modified-id="Проверка-расчета-эффективности-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Проверка расчета эффективности</a></span></li><li><span><a href="#Преданализ-обучающей-и-тестовой-выборки" data-toc-modified-id="Преданализ-обучающей-и-тестовой-выборки-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Преданализ обучающей и тестовой выборки</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Замена-пустых-значений" data-toc-modified-id="Замена-пустых-значений-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Замена пустых значений</a></span></li></ul></li><li><span><a href="#Удаление-производных-признаков-обучающей-выборки" data-toc-modified-id="Удаление-производных-признаков-обучающей-выборки-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Удаление производных признаков обучающей выборки</a></span></li><li><span><a href="#Удаление-возможных-целевых-признаков-обучающей-выборки" data-toc-modified-id="Удаление-возможных-целевых-признаков-обучающей-выборки-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Удаление возможных целевых признаков обучающей выборки</a></span></li><li><span><a href="#Оценка-корреляции-признаков-и-удаление-лишних-в-обучающей-выборке" data-toc-modified-id="Оценка-корреляции-признаков-и-удаление-лишних-в-обучающей-выборке-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Оценка корреляции признаков и удаление лишних в обучающей выборке</a></span></li><li><span><a href="#Добавление-целевого-признака-в-тестовую-выборку" data-toc-modified-id="Добавление-целевого-признака-в-тестовую-выборку-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Добавление целевого признака в тестовую выборку</a></span></li><li><span><a href="#Удаление-лишних-высококоррелирующих-признаков-в-тестовой-выборке" data-toc-modified-id="Удаление-лишних-высококоррелирующих-признаков-в-тестовой-выборке-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Удаление лишних высококоррелирующих признаков в тестовой выборке</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Оценка-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Оценка-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Оценка концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Cравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Cравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cравнение распределения размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях</a></span><ul class="toc-item"><li><span><a href="#Оценим-начальные-концентрации-металлов" data-toc-modified-id="Оценим-начальные-концентрации-металлов-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Оценим начальные концентрации металлов</a></span></li><li><span><a href="#Оценим-концентрации-на-последующих-этапах-(выход-с-этапа)" data-toc-modified-id="Оценим-концентрации-на-последующих-этапах-(выход-с-этапа)-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Оценим концентрации на последующих этапах (выход с этапа)</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучение-разных-моделей-и-оценка-их-качества-кросс-валидацией" data-toc-modified-id="Обучение-разных-моделей-и-оценка-их-качества-кросс-валидацией-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение разных моделей и оценка их качества кросс-валидацией</a></span><ul class="toc-item"><li><span><a href="#Разделение-признаков-и-целевые-значений" data-toc-modified-id="Разделение-признаков-и-целевые-значений-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Разделение признаков и целевые значений</a></span></li><li><span><a href="#Приведение-данных-к-единому-масштабу" data-toc-modified-id="Приведение-данных-к-единому-масштабу-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Приведение данных к единому масштабу</a></span></li><li><span><a href="#Загрузка-моделей,-создание-make_scorer-и-проверка-кросс-валидацией" data-toc-modified-id="Загрузка-моделей,-создание-make_scorer-и-проверка-кросс-валидацией-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Загрузка моделей, создание make_scorer и проверка кросс-валидацией</a></span></li></ul></li><li><span><a href="#Подборка-гипер-параметров-на-обучающей-выборке" data-toc-modified-id="Подборка-гипер-параметров-на-обучающей-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Подборка гипер-параметров на обучающей выборке</a></span><ul class="toc-item"><li><span><a href="#Целевой-признак---'rougher.output.recovery'" data-toc-modified-id="Целевой-признак---'rougher.output.recovery'-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Целевой признак - 'rougher.output.recovery'</a></span></li><li><span><a href="#Целевой-признак---'final.output.recovery'" data-toc-modified-id="Целевой-признак---'final.output.recovery'-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Целевой признак - 'final.output.recovery'</a></span></li></ul></li><li><span><a href="#Лучшая-модель-и-проверка-её-на-тестовой-выборке" data-toc-modified-id="Лучшая-модель-и-проверка-её-на-тестовой-выборке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Лучшая модель и проверка её на тестовой выборке</a></span></li><li><span><a href="#Проверка-тестовых-данных-моделью-&quot;Dummy&quot;" data-toc-modified-id="Проверка-тестовых-данных-моделью-&quot;Dummy&quot;-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Проверка тестовых данных моделью "Dummy"</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовить прототип модели машинного обучения для комании, которая разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# # Технологический процесс #

# %% [markdown]
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# 1. Флотация:
# - Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# - На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# 2. Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# `Описание данных`
#
# 1. *Технологический процесс:*
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     - Xanthate **— ксантогенат (промотер, или активатор флотации);
#     - Sulphate — сульфат (на данном производстве сульфид натрия);
#     - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
# 2. *Параметры этапов*
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# `Наименование признаков`
#
# - Наименование признаков должно быть такое: [этап].[тип_параметра].[название_параметра]
# - Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики
#
# `Расчёт эффективности`
#
# Эффективность обогащения рассчитывается по формуле:
#
# **recovery = (Cx(F-T) / Fx(C-T))x100%**
#
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# `Нужно спрогнозировать сразу две величины:`
# 1. Эффективность обогащения чернового концентрата - rougher.output.recovery;
# 2. Эффективность обогащения финального концентрата - final.output.recovery.

# %% [markdown]
# ## Подготовка данных

# %%
# импорт требуемых библиотек

import pandas as pd #программная библиотека для обработки и анализа данных. Работа pandas с данными строится поверх библиотеки NumPy
import numpy as np #поддержка многомерных массивов; поддержка высокоуровневых математических функций, предназначенных для работы с многомерными массивами
import matplotlib.pyplot as plt #библиотека для визуализации данных двумерной графикой
import seaborn as sns #библиотека для построения простых графиков и цветовых матриц

from sklearn.metrics import mean_absolute_error              #расчет среднего абсолютного отклонения
from sklearn.metrics import make_scorer                      #инструмен для реализации функции как метрики модели
from sklearn.model_selection import cross_val_score          #расчет среднего значения метрики на кросс-валидации

from sklearn.preprocessing import StandardScaler             #инструмент масштабирования числовых данных

from sklearn.tree import DecisionTreeRegressor               #алгоритм регрессии "случайным деревом"
from sklearn.ensemble import RandomForestRegressor           #алгоритм регрессии "случайным лесом"
from sklearn.linear_model import LinearRegression            #алгоритм линейная регрессия

from sklearn.model_selection import GridSearchCV             #инпортируем инструмент кросс-валидации и обучения модели

# %%
df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv') #серверный путь / обучающая выборка
df_train.name = 'df_train' #присвоим имя датафрейму

df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv') #серверный путь / тестовая выборка
df_test.name = 'df_test' #присвоим имя датафрейму

df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv') #серверный путь /  исходные данные
df_full.name = 'df_full' #присвоим имя датафрейму

# %%
df_train.tail(2)
# Out:
#                       date  final.output.concentrate_ag  \
# 14147  2018-08-18 09:59:59                     3.367241
# 14148  2018-08-18 10:59:59                     3.598375
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 14147                    11.625587                      6.799433
# 14148                    11.737832                      6.717509
#
#        final.output.concentrate_au  final.output.recovery  \
# 14147                    46.408188              65.523246
# 14148                    46.299438              70.281454
#
#        final.output.tail_ag  final.output.tail_pb  final.output.tail_sol  \
# 14147              8.777171              2.819214              10.463847
# 14148              8.406690              2.517518              10.652193
#
#        final.output.tail_au  ...  secondary_cleaner.state.floatbank4_a_air  \
# 14147              1.602879  ...                                 23.024963
# ...

# %%
df_test.head(2)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                             8.08
# 1                         14.987471                             8.08
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# ...

# %%
df_full.loc[14147:14150]
# Out:
#                       date  final.output.concentrate_ag  \
# 14147  2017-11-21 02:59:59                     6.525446
# 14148  2017-11-21 03:59:59                     6.697472
# 14149  2017-11-21 04:59:59                     6.497358
# 14150  2017-11-21 05:59:59                     6.222565
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 14147                    11.052516                     10.470576
# 14148                    11.690612                     10.498243
# 14149                    11.536106                     10.269441
# 14150                    11.567462                     10.318221
#
#        final.output.concentrate_au  final.output.recovery  \
# 14147                    43.312429              78.818682
# 14148                    42.524793              79.082827
# 14149                    42.385740              79.315290
# 14150                    43.297608              77.673257
#
# ...

# %% [markdown]
# - **Данные по дате в датафреймах различаются: есть округленные до часов, есть уменьшенные на минуту.**
# - В сводном дата фрейме тестовая выборка не идет сразу после обучающей.
#     - К примеру, строка #1 тестовой выборки, это строка #4682 в сводном датафрейме.

# %% [markdown]
# Найдем значение 'primary_cleaner.input.sulfate' в тестовой и сводной выборке на дату 2016-09-01 00:59:59 - начало тестовой

# %%
df_full['primary_cleaner.input.sulfate'].loc[df_full['date'] == "2016-09-01 00:59:59"]
# Out:
# 4682    210.800909
# Name: primary_cleaner.input.sulfate, dtype: float64

# %% [markdown]
# Найдем значение 'primary_cleaner.input.sulfate' и номер строки в тестовой и сводной выборке на дату 2017-12-31 23:59:59 - конец тестовой

# %%
df_full['primary_cleaner.input.sulfate'].loc[df_full['date'] == "2017-12-31 23:59:59"]
# Out:
# 15059    181.556856
# Name: primary_cleaner.input.sulfate, dtype: float64

# %% [markdown]
# `В тестовую выборку не попали данные из примерно первых и последних 4500 тыс. строк, что грубо составляет половину всего сводного датафрейма. Результаты работы модели по тестовой выборке могут быть не репрезентативны.`

# %%
df_list = [df_train, df_test, df_full] #список датафреймов для работы в циклах

for df_ in df_list:
    df_.info()
    print()
    print(df_.isna().sum())
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %% [markdown]
# - **Дата в всех датафреймах в текстором формате.**

# %% [markdown]
# ### Проверка расчета эффективности

# %% [markdown]
# - Вычислите значение на обучающей выборке для признака rougher.output.recovery.
# - Найти MAE между вашими расчётами и значением признака.

# %%
df_train['rougher.output.recovery'].describe() #табличные данные по значению обогащению/восстановления на этапе флотации
# Out:
# count    14149.000000
# mean        82.704502
# std         14.479156
# min          0.000000
# 25%         79.993067
# 50%         85.299462
# 75%         90.165021
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %% [markdown]
# `Расчёт эффективности`
#
# + C — доля золота в концентрате после флотации = 'rougher.output.concentrate_au'
# + F — доля золота в сырье/концентрате до флотации =  'rougher.input.feed_au'
# + T — доля золота в отвальных хвостах после флотации/очистки = 'rougher.output.tail_au'

# %% [markdown]
# ![Recovery_1576238822.jpg](attachment:Recovery_1576238822.jpg)

# %%
#расчет эффективности обогащения по табличным данным

df_train['rougher.calculation.recovery'] =(
    df_train['rougher.output.concentrate_au'] * (df_train['rougher.input.feed_au'] - df_train['rougher.output.tail_au'])) /\
    (df_train['rougher.input.feed_au'] * (df_train['rougher.output.concentrate_au'] - df_train['rougher.output.tail_au'])) * 100

# %%
df_train['rougher.calculation.recovery'].describe() #расчетные данные по значению обогащению/восстановления на этапе флотации
# Out:
# count    14149.000000
# mean        82.704502
# std         14.479156
# min         -0.000000
# 25%         79.993067
# 50%         85.299462
# 75%         90.165021
# max        100.000000
# Name: rougher.calculation.recovery, dtype: float64

# %%
#расчет среднего абсолютного отклонения

MAE_recovery = mean_absolute_error(df_train['rougher.calculation.recovery'], df_train['rougher.output.recovery'])

print("Среднее абсолютное отклонение для расчетной и табличной величины восстановления золота:", MAE_recovery)
# Out:
# Среднее абсолютное отклонение для расчетной и табличной величины восстановления золота: 9.73512347450521e-15

# %% [markdown]
# **Вывод:**
# Значение ошибка МАЕ стремится к нулю, очень маленькое значение, что подтверждает верность табличных данных.

# %% [markdown]
# ### Преданализ обучающей и тестовой выборки

# %% [markdown]
# - Проанализировать признаки, недоступные в тестовой выборке.
# - Что это за параметры?
# - К какому типу относятся?

# %%
display("Размер обучающей выборки:", df_train.shape)
display("Размер тестовой выборки:", df_test.shape)
# Out:
# 'Размер обучающей выборки:'
# (14149, 88)
# 'Размер тестовой выборки:'
# (5290, 53)

# %%
#список уникальный столбцов обучающей выборки, которых нет в тестовой
sorted(df_train.columns.difference(df_test.columns))
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.recovery',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
# ...

# %%
print("Всего пропущено столбцов:", pd.Series(df_train.columns.difference(df_test.columns)).count())
# Out:
# Всего пропущено столбцов: 35

# %% [markdown]
# **Вывод:**
# 1. Значения относятся к блокам [тип_параметра]:
#     - output — параметры продукта, выходные данные;
#     - calculation — расчётные характеристики на базе выходных данных.
# 2. Все пропущенные столбцы могут быть отнесены к целевому признаку в зависимости от поставленной задачи.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Поиск дубликатов

# %%
#поиск дубликатов в датафреймах в цикле по списку:
for df_ in df_list:
    print(f'Количество явных дубликатов под удаление {df_.name}: {df_.duplicated().sum()}') #подсчёт явных дубликатов
# Out:
# Количество явных дубликатов под удаление df_train: 0
# Количество явных дубликатов под удаление df_test: 0
# Количество явных дубликатов под удаление df_full: 0

# %% [markdown]
# #### Замена пустых значений

# %% [markdown]
# - Данные индексируются датой и временем получения информации (признак date).
# - Соседние по времени параметры часто похожи. В связи с этим заполним пробелы в данных предудущим значением только для полного датафрейма - df_full.
# - Так как обучающая и тестовая выборки созданы из основного датафрейма, соберем их занового по индексам - дате.

# %%
df_full.fillna(method='ffill', inplace=True)          #заполняем методом forward fill сводную выборку / исходные данные

# %%
df_full = df_full.set_index('date')                   #для сводного датафрейма сделаем дату индексом

# %%
df_train_index = df_train.set_index('date').index     #для обучающей выборки сделаем дату индексом и соберем в список
df_train = df_full.loc[df_train_index]                #соберем обучающий датафрейм заново из полного, в котором заполнены пропуски
df_train.name = 'df_train'                            #присвоим имя датафрейму

# %%
df_test_dateindex = df_test.set_index('date')         #для тестовой выборки сделаем дату индексом
test_columns = df_test_dateindex.columns              #оставим болько нужные нам столбцы, т.к. эта выборка усеченная
df_test_index = df_test_dateindex.index               #соберем индексы тестового датафрейма
df_test = df_full[test_columns].loc[df_test_index]    #соберем тестовый датафрейм заново из полного, в котором заполнены пропуски
df_test.name = 'df_test' #присвоим имя датафрейму

# %%
df_train.isna().sum() #проверка успешности замены
# Out:
# final.output.concentrate_ag                   0
# final.output.concentrate_pb                   0
# final.output.concentrate_sol                  0
# final.output.concentrate_au                   0
# final.output.recovery                         0
#                                              ..
# secondary_cleaner.state.floatbank5_a_level    0
# secondary_cleaner.state.floatbank5_b_air      0
# secondary_cleaner.state.floatbank5_b_level    0
# secondary_cleaner.state.floatbank6_a_air      0
# secondary_cleaner.state.floatbank6_a_level    0
# Length: 86, dtype: int64

# %% [markdown]
# ### Удаление производных признаков обучающей выборки

# %%
#удалим из обучающей выборки все колонки с расчетными характеристиками как производные - calculation
df_train_cut = df_train[df_train.columns.drop(list(df_train.filter(regex='calculation')))] 

df_train_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 82 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   final.output.concentrate_ag                 14149 non-null  float64
#  1   final.output.concentrate_pb                 14149 non-null  float64
#  2   final.output.concentrate_sol                14149 non-null  float64
#  3   final.output.concentrate_au                 14149 non-null  float64
#  4   final.output.recovery                       14149 non-null  float64
#  5   final.output.tail_ag                        14149 non-null  float64
#  6   final.output.tail_pb                        14149 non-null  float64
#  7   final.output.tail_sol                       14149 non-null  float64
#  8   final.output.tail_au                        14149 non-null  float64
# ...

# %% [markdown]
# ### Удаление возможных целевых признаков обучающей выборки

# %%
#выделим оба целеых признака

df_train_tar = df_train[['final.output.recovery','rougher.output.recovery']]

# %%
#удалим из обучающей выборки все колонки выходными параметрами, которые могут быть целевыми признаками

df_train_cut = df_train_cut[df_train_cut.columns.drop(list(df_train_cut.filter(regex='output')))] 

#вернем в обучающую выборку целевые признаки

df_train_cut = df_train_cut.join(df_train_tar)

sorted(df_train_cut.columns)
# Out:
# ['final.output.recovery',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_a_level',
#  'primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'primary_cleaner.state.floatbank8_d_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_au',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.recovery',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
# ...

# %% [markdown]
# ### Оценка корреляции признаков и удаление лишних в обучающей выборке

# %%
#оценим корреляцию признаков между собой
df_train_cut_cor = df_train_cut.corr() #составляем полную матрицу корреляции (коэффициент Пирсона)

threshold = 0.9 #зададим порог

#фильтруем данные по коээфициентам или меньше/больше или равно -порог/+порог и не равно 1
df_train_cut_cor_filtered = df_train_cut_cor[((df_train_cut_cor<=-(threshold)) | (df_train_cut_cor>=threshold)) & (df_train_cut_cor!=1.0)]

# %%
plt.figure(figsize=(15,13)) #построим график, используя seaborn

sns.heatmap(df_train_cut_cor_filtered,annot=True) #построим тепловую карту фильтрованной матрицы корреляции

plt.show() #отобрразим плот-график

# %% [markdown]
# **Вывод:** Определить визуально пары столбцов с высокими коээфициентами корреляции не представляется возможным, матрица нечитаема, необходим другой подход.

# %%
#"разбираем" матрицу
#убираем пропуски, которые появились после фильтрации
#сортируем коээфициенты по убыванию
#убираем дубликаты, т.к. матрица "зеркальна" // 
#скидываем индексы, чтобы получить таблицу с парами коррелирующих колонок

high_cor_df = df_train_cut_cor_filtered.unstack()\
            .dropna()\
            .sort_values(ascending=False)\
            .drop_duplicates()\
            .reset_index(drop=False)

display(high_cor_df)
# Out:
#                                        level_0  \
# 0            rougher.state.floatbank10_e_level
# 1            rougher.state.floatbank10_c_level
# 2            rougher.state.floatbank10_c_level
# 3            rougher.state.floatbank10_c_level
# 4            rougher.state.floatbank10_d_level
# 5            rougher.state.floatbank10_f_level
# 6            rougher.state.floatbank10_e_level
# 7            rougher.state.floatbank10_d_level
# 8            rougher.state.floatbank10_e_level
# 9            rougher.state.floatbank10_f_level
# 10    primary_cleaner.state.floatbank8_b_level
# 11    primary_cleaner.state.floatbank8_c_level
# 12      primary_cleaner.state.floatbank8_a_air
# 13      primary_cleaner.state.floatbank8_b_air
# 14    primary_cleaner.state.floatbank8_c_level
# 15             rougher.state.floatbank10_c_air
# 16      primary_cleaner.state.floatbank8_a_air
# 17             rougher.state.floatbank10_e_air
# 18             rougher.state.floatbank10_b_air
# ...

# %% [markdown]
# Всего 21 пара коррелирующих между собой признаков, среди которых надо оставить только по одному.

# %%
#создадим цикл по индексам Х-оси матрицы с длиной равной количеству столбцов
#создадим цикл по индексам Y-оси с длиной равной X-оси 
#если модуль значения на пересечении выше целевого порога и название столбца Y-оси не в списке, то
#название столбца по X-оси добавляем в новый список под удаление
#отображаем отсортированный список под удаление

del_corr_columns = []

for i in range(len(df_train_cut_cor_filtered.columns)):
    for j in range(i):
        if (abs(df_train_cut_cor_filtered.iloc[i,j]) > threshold) and (df_train_cut_cor_filtered.columns[j] not in del_corr_columns):
            del_corr_columns.append(df_train_cut_cor_filtered.columns[i])
display(sorted(del_corr_columns))
print("Количество столбцов под удаление:", len(del_corr_columns))
# Out:
# ['primary_cleaner.state.floatbank8_b_air',
#  'primary_cleaner.state.floatbank8_b_level',
#  'primary_cleaner.state.floatbank8_c_air',
#  'primary_cleaner.state.floatbank8_c_level',
#  'rougher.state.floatbank10_c_air',
#  'rougher.state.floatbank10_c_level',
#  'rougher.state.floatbank10_d_air',
#  'rougher.state.floatbank10_d_level',
#  'rougher.state.floatbank10_e_level',
#  'rougher.state.floatbank10_f_air',
#  'rougher.state.floatbank10_f_level',
#  'secondary_cleaner.state.floatbank2_b_level']
# Количество столбцов под удаление: 12

# %%
df_train_fin = df_train_cut.drop(columns=del_corr_columns) #удалим столбцы с высокой корреляций признаков друг с другом
df_train_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               14149 non-null  float64
#  1   primary_cleaner.input.depressant            14149 non-null  float64
#  2   primary_cleaner.input.feed_size             14149 non-null  float64
#  3   primary_cleaner.input.xanthate              14149 non-null  float64
#  4   primary_cleaner.state.floatbank8_a_air      14149 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_level    14149 non-null  float64
#  6   primary_cleaner.state.floatbank8_d_air      14149 non-null  float64
#  7   primary_cleaner.state.floatbank8_d_level    14149 non-null  float64
#  8   rougher.input.feed_ag                       14149 non-null  float64
# ...

# %%
plt.figure(figsize=(15,13)) #построим график для обновленного дадафрейма, используя seaborn

sns.heatmap(df_train_fin.corr(), cmap="Blues", vmin=-1, vmax=1, linewidths=.5) #построим тепловую карту фильтрованной матрицы корреляции

plt.show() #отобрразим плот-график

# %% [markdown]
# **Вывод**:
# - Тестовый датафрейм успешно подготовлен для дальнейшего разделения на признаки и целевой признак - 'final.output.recovery'.
# - Признаки с высокой корреляций друг с другом удалены.

# %% [markdown]
# ### Добавление целевого признака в тестовую выборку

# %%
df_test_fin = df_test.join(df_full[['final.output.recovery','rougher.output.recovery']])

# %%
df_test_fin.head(1)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# ...

# %%
df_test_fin.tail(1)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2017-12-31 23:59:59                     181.556856
#
#                      primary_cleaner.input.depressant  \
# date
# 2017-12-31 23:59:59                          14.99585
#
#                      primary_cleaner.input.feed_size  \
# date
# 2017-12-31 23:59:59                             8.07
#
#                      primary_cleaner.input.xanthate  \
# date
# 2017-12-31 23:59:59                        1.623454
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2017-12-31 23:59:59                             1498.096303
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2017-12-31 23:59:59                               -499.796922
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2017-12-31 23:59:59                             1501.743791
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# ...

# %% [markdown]
# Найдем: в основном **df_full** датафрейме `final.output.recovery` на дату и проверим успешность объединения:
# - 2016-09-01 00:59:59 - 70.273583
# - 2017-12-31 23:59:59 - 71.699976

# %%
print("Значение `final.output.recovery` на заданную дату:", df_full['final.output.recovery'].loc["2016-09-01 00:59:59"])
# Out:
# Значение `final.output.recovery` на заданную дату: 70.27358301287518

# %%
print("Значение `final.output.recovery` на заданную дату:", df_full['final.output.recovery'].loc["2017-12-31 23:59:59"])
# Out:
# Значение `final.output.recovery` на заданную дату: 71.69997575778707

# %% [markdown]
# **Вывод:** Целевой признак успешно добавлен к тестовому датафрейму.

# %% [markdown]
# ### Удаление лишних высококоррелирующих признаков в тестовой выборке

# %%
df_test_fin = df_test_fin.drop(columns=del_corr_columns)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Оценка концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
#концентрация золота для каждого этапа очистки

tech_steps_au = [
    'rougher.output.concentrate_au',
    'primary_cleaner.output.concentrate_au',
    'final.output.concentrate_au'
]

# %%
#посмотрим концентрацию на исходном обучающем датафрейме до удаления целевых признаков

for step in tech_steps_au:
    df_train[step].hist(bins=50, alpha=0.7, legend=True, figsize=(15,5)).set_xlabel('Концентрация')

# %%
#концентрация серебра для каждого этапа очистки

tech_steps_ag = [
    'rougher.output.concentrate_ag',
    'primary_cleaner.output.concentrate_ag',
    'final.output.concentrate_ag'
]

# %%
for step in tech_steps_ag:
    df_train[step].hist(bins=50, alpha=0.7, legend=True, figsize=(15,5)).set_xlabel('Концентрация')

# %%
#концентрация свинца для каждого этапа очистки

tech_steps_pb = [
    'rougher.output.concentrate_pb',
    'primary_cleaner.output.concentrate_pb',
    'final.output.concentrate_pb'
]

# %%
for step in tech_steps_pb:
    df_train[step].hist(bins=50, alpha=0.7, legend=True, figsize=(15,5)).set_xlabel('Концентрация')

# %% [markdown]
# **Вывод**:
#
# 1. Концентрация золота в выходном продукте от этапа к этапу становится выше, что отображают гистограммы распределения.
# 2. Концентрация серебра в выходном продукте от этапа к этапу снижается.
# 3. Концентрация свинца при переходе с флотации до первого этапа очистки увеличивается, а потом остается неизменной при выходе со второго этапа.

# %% [markdown]
# ### Cравнение распределения размеров гранул сырья на обучающей и тестовой выборках

# %%
#построим графики типа бокс-плот с заданными характеристиками для датафреймов и столбца - 'rougher.input.feed_size'

feed_size_list = [df_train, df_test]           #список датафреймов для анализа

for df in feed_size_list:
    df['rougher.input.feed_size'].plot(
        kind='box',                            #тип графика
        title=f'Grain size {df.name}',         #название графика
        grid=True,                             #отображение сетки
        color='blue',                          #цвет графика
        figsize=(15,1),                        #размер графика
        xlim=(0,500),                          #шкала графика
        xticks = range(0,500,50),              #шаг по шкале - 50
        vert = 0                               #развернуть график горизонтально
)
    plt.show()

# %% [markdown]
# **Выводы**:
# - Размер зерна на обучающей выборке незначительно больше, чем на тестовой выборке судя по медиане / Q2 - второму квартилю.
# - В тоже время, на обучающей выборке в целом больше выбросов, больших значений размера зерна: от 150 и выше.

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях

# %% [markdown]
# Проверка справедлива для обучающей выборки, т.к. тестовая не содержит целевых признаков.

# %% [markdown]
# #### Оценим начальные концентрации металлов

# %%
#оценим начальные концентрации металлов

input_feed_metal = [
    'rougher.input.feed_au',
    'rougher.input.feed_ag',
    'rougher.input.feed_pb',
    'rougher.input.feed_sol'
]

# %%
#посмотрим концентрацию на исходном обучающем датафрейме до удаления целевых признаков

for input_feed in input_feed_metal:
    df_train[input_feed].hist(bins=50, alpha=0.7, legend=True, figsize=(15,5)).set_xlabel('Начальные концентрации элементов')

# %% [markdown]
# Начальные концентрации металлов не превышают 15%, в большинстве случаев значительно меньше 10%.

# %% [markdown]
# #### Оценим концентрации на последующих этапах (выход с этапа)

# %%
#посмотрим концентрацию на исходном обучающем датафрейме до удаления целевых признаков

#напишем функцию для суммирования столбцов и вывода результата

step_list = ['rougher','primary_cleaner','final']

def concentration(row):

    concent_list = []
    
    for step in step_list:                                    #перебираем этапы очистки золота от породы
        ag = row[step+".output.concentrate_ag"]
        au = row[step+".output.concentrate_au"]
        pb = row[step+".output.concentrate_pb"]
        sol = row[step+".output.concentrate_sol"]
    
        concent =  ag + au + pb + sol
        
        concent_list.append(concent)
    
    return pd.Series(concent_list)

# %%
df_concent = df_train.apply(concentration, axis=1)

# %%
df_concent.columns = step_list

# %%
df_concent.head(3)
# Out:
#                        rougher  primary_cleaner      final
# date
# 2016-01-15 00:00:00  66.424950        72.640924  63.644396
# 2016-01-15 01:00:00  67.012710        72.543485  63.957723
# 2016-01-15 02:00:00  66.103793        72.095042  64.311180

# %%
df_concent['rougher'].hist(bins=50,figsize=(15,5),alpha = 0.7, legend=True)
df_concent['primary_cleaner'].hist(bins=50,figsize=(15,5), color='green',alpha = 0.7, legend=True)
df_concent['final'].hist(bins=50,figsize=(15,5), color='grey',alpha = 0.7, legend=True)
# Out:
# <AxesSubplot:>

# %%
print(df_concent.describe())
# Out:
#             rougher  primary_cleaner         final
# count  14149.000000     14149.000000  14149.000000
# mean      67.173145        60.172546     68.387872
# std       12.713129        10.448165      7.023723
# min        0.000000         0.000000      0.000000
# 25%       64.914390        58.046816     67.559819
# 50%       69.175663        61.786946     69.141502
# 75%       73.429261        65.355951     70.974661
# max       88.140119        76.918076     80.210644

# %% [markdown]
# На всех этапах  присутствуют нулевые значения сумммы концентрации веществ, вероятно ошибка: необходимо уточнить со специалистами по выгрузке данных. В данном случае удалим строки с концентрацией веществ на начальном этапе и в конце <=5%.

# %%
df_concent_index = df_concent.query('rougher  <= 5 or final  <= 5').index  #соберем дата-индексы, гле концентрация <5%

# %%
print(f'Всего надо удалить строк по индексам: {len(df_concent_index)}') #всего N-индексов под удаление
# Out:
# Всего надо удалить строк по индексам: 360

# %%
df_train_fin = df_train_fin.drop(index=df_concent_index)

# %%
print(f'Размер обновленного обучающего датафрейма: строк - {df_train_fin.shape[0]}, столбцов - {df_train_fin.shape[1]}.')
# Out:
# Размер обновленного обучающего датафрейма: строк - 13789, столбцов - 42.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE

# %% [markdown]
# ![smape_1576238825.jpg](attachment:smape_1576238825.jpg)

# %%
def smape(target, prediction):                    #входные параметры: таргет и прогноз
    smape = sum((np.abs(target - prediction)/((np.abs(target)+np.abs(prediction))/2)))/len(target)*100  #первый расчет
    return smape

# %%
#тестирование функции на рандомных данных:

tar_test = [42, 34, -36]
pred_test = [38, 32, -42]

smape_fin = smape(pd.Series(tar_test), pd.Series(pred_test))
print(smape_fin)
# Out:
# 10.481740481740482

# %% [markdown]
# **Вывод:** Формула успешно реализована и проверена на рандомных тестовых данных.

# %% [markdown]
# ### Обучение разных моделей и оценка их качества кросс-валидацией

# %% [markdown]
# #### Разделение признаков и целевые значений

# %%
# Деление обучающей выборки: признаки и целевой признак

features_train = df_train_fin.drop(columns=['rougher.output.recovery','final.output.recovery'])   #обучающий датафрейм по "признакам"
target_train_1 = df_train_fin['rougher.output.recovery']                  #обучающий датафрейм по "целевому признаку №1"
target_train_2 = df_train_fin['final.output.recovery']                    #обучающий датафрейм по "целевому признаку №2"

# %%
features_train.columns #для первого этапа очистки 'rougher' включены этапы, которые появляются позднее
# Out:
# Index(['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.feed_size', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_a_level',
#        'primary_cleaner.state.floatbank8_d_air',
#        'primary_cleaner.state.floatbank8_d_level', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_size', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_sulfate',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_sulfate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
#        'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_e_air',
#        'secondary_cleaner.state.floatbank2_a_air',
# ...

# %%
features_train_rog = features_train[features_train.columns.drop(list(features_train.filter(regex='primary_cleaner')))]

# %%
features_train_rog = features_train_rog[features_train_rog.columns.drop(list(features_train_rog.filter(regex='secondary_cleaner')))]

# %%
sorted(features_train_rog.columns)
# Out:
# ['rougher.input.feed_ag',
#  'rougher.input.feed_au',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.feed_sol',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'rougher.state.floatbank10_e_air']

# %%
# Деление тестовой выборки: признаки и целевой признак

features_test = df_test_fin.drop(columns=['rougher.output.recovery','final.output.recovery'])   #тестовый датафрейм по "признакам"
target_test_1 = df_test_fin['rougher.output.recovery']                  #тестовый датафрейм по "целевому признаку №1"
target_test_2 = df_test_fin['final.output.recovery']                    #тестовый датафрейм по "целевому признаку №2"

# %%
features_test_rog = features_test[features_test.columns.drop(list(features_test.filter(regex='primary_cleaner')))]

# %%
features_test_rog = features_test_rog[features_test_rog.columns.drop(list(features_test_rog.filter(regex='secondary_cleaner')))]

# %%
features_test_rog.shape[1] == features_train_rog.shape[1] #количество столбцов одинаково в обучающей и тестовой выборке?
# Out:
# True

# %%
features_train_rog.columns == features_train_rog.columns #имена столбцов одинаковые?
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %% [markdown]
# #### Загрузка моделей, создание make_scorer и проверка кросс-валидацией

# %%
model_tree  = DecisionTreeRegressor(random_state=42)       #дерево решений регрессии
model_forest = RandomForestRegressor(random_state=42)      #случайный лес регрессии   
model_regres = LinearRegression()                          #линейная регрессия

# %%
smape_scorer = make_scorer(smape, greater_is_better = True) # Создадим скорер для реализации функции как метрики модели

# %%
model_list = [model_regres,model_forest,model_tree] #создание списка моделе для обучающей выборки для перебора в цикле

# %%
# %%time

smape_scores_list_rog = []                  #соберем все значения для таргета 1

for model_ in model_list:                   #перебираем модели в цикле
        smape_scores_rog = cross_val_score(model_, features_train_rog, target_train_1, cv=5, scoring = smape_scorer) #считаем метрику, в которую защита функция sMAPE
        smape_scores_list_rog.append(smape_scores_rog.mean()) #собираем средние значения от 5 итераций кросс-валидации
                
print(smape_scores_list_rog)                              #высодим список на экран
# Out:
# [6.578351853439711, 6.379139967635518, 9.177312198755953]
# CPU times: user 1min 31s, sys: 904 ms, total: 1min 32s
# Wall time: 1min 35s

# %%
# %%time

smape_scores_list_fin = []                  #соберем все значения для таргета 1

for model_ in model_list:                   #перебираем модели в цикле
        smape_scores_fin = cross_val_score(model_, features_train, target_train_2, cv=5, scoring = smape_scorer) #считаем метрику, в которую защита функция sMAPE
        smape_scores_list_fin.append(smape_scores_fin.mean()) #собираем средние значения от 5 итераций кросс-валидации
                
print(smape_scores_list_fin)                              #высодим список на экран
# Out:
# [10.80597451511608, 9.557012493711609, 15.064032047623826]
# CPU times: user 5min 20s, sys: 1.51 s, total: 5min 21s
# Wall time: 5min 23s

# %%
#преобразуем список в датафрейм для наглядности полученных результатов

df_smape = pd.DataFrame(data=[smape_scores_list_rog,smape_scores_list_fin],\
                   index=['rougher',
                          'final'],\
                   columns = ['model_regres', 'model_forest', 'model_tree'])

# %%
df_smape
# Out:
#          model_regres  model_forest  model_tree
# rougher      6.578352      6.379140    9.177312
# final       10.805975      9.557012   15.064032

# %% [markdown]
# ![_smape_1576238814.jpg](attachment:_smape_1576238814.jpg)

# %%
total_smape_regres = round((0.25*df_smape['model_regres'][0] + 0.75*df_smape['model_regres'][1]),4)
total_smape_forest = round((0.25*df_smape['model_forest'][0] + 0.75*df_smape['model_forest'][1]),4)
total_smape_tree = round((0.25*df_smape['model_tree'][0] + 0.75*df_smape['model_tree'][1]),4)

print(f'Итоговое значнение sMAPE "линейная регрессия": {total_smape_regres}')
print(f'Итоговое значнение sMAPE "случайный лес": {total_smape_forest}')
print(f'Итоговое значнение sMAPE "дерево": {total_smape_tree}')
# Out:
# Итоговое значнение sMAPE "линейная регрессия": 9.7491
# Итоговое значнение sMAPE "случайный лес": 8.7625
# Итоговое значнение sMAPE "дерево": 13.5924

# %%
def total_smape(smape_rog, smape_fin):
    total_smape = round((smape_rog*0.25 + smape_fin*0.75),4)
    return total_smape

# %%
total_smape_regres_def = total_smape(df_smape['model_regres'][0],df_smape['model_regres'][1])
total_smape_forest_def = total_smape(df_smape['model_forest'][0],df_smape['model_forest'][1])
total_smape_tree_def = total_smape(df_smape['model_tree'][0],df_smape['model_tree'][1])

# %%
print(f'Итоговое значнение sMAPE "линейная регрессия": {total_smape_regres_def}')
print(f'Итоговое значнение sMAPE "случайный лес": {total_smape_forest_def}')
print(f'Итоговое значнение sMAPE "дерево": {total_smape_tree_def}')
# Out:
# Итоговое значнение sMAPE "линейная регрессия": 9.7491
# Итоговое значнение sMAPE "случайный лес": 8.7625
# Итоговое значнение sMAPE "дерево": 13.5924

# %% [markdown]
# **Вывод**: Модель "случайный лес" показала наилучший результат по метрики модели sMAPE.

# %% [markdown]
# ### Подборка гипер-параметров на обучающей выборке

# %% [markdown]
# #### Целевой признак - 'rougher.output.recovery'

# %%
# %%time

grid_list_rog = []

param_grid = [{'max_depth': list(range(5, 26, 5)),       #глубина дерева от 5 до 20 с шагом 5
               'n_estimators': list(range(1, 31, 5))}]       #деревьев в лесу от 1 до 3

grid_1 = GridSearchCV(model_forest,                      #модель для кросс-валидации
                      param_grid,                        #параметры для перебора
                      scoring=smape_scorer,              #метрика оценки модели
                      cv=5).fit(features_train_rog, target_train_1)  #количество блоков кросс-валидации

grid_list_rog = grid_1.cv_results_['mean_test_score']    #найдем среднее значение нашей метрики на каждой итерации

#print(grid_1.best_params_)                              #вывод лучшей комбинации параметров для одиничного значения
# Out:
# CPU times: user 4min 42s, sys: 275 ms, total: 4min 43s
# Wall time: 4min 47s

# %%
display(grid_list_rog)       
print("Количество итераций:", len(grid_list_rog))
# Out:
# array([7.11592545, 6.62069192, 6.57973487, 6.5419972 , 6.54062979,
#        6.5295493 , 7.70337232, 6.83606339, 6.67277597, 6.61091466,
#        6.61002904, 6.69885696, 8.17644056, 6.63809147, 6.51977893,
#        6.50902362, 6.56876608, 6.63469385, 8.55255969, 6.88922165,
#        6.63539035, 6.5688578 , 6.589107  , 6.64005242, 8.39243998,
#        6.69818051, 6.53056607, 6.50471496, 6.58771546, 6.65467006])
# Количество итераций: 30

# %%
min_value_train_rog = min(grid_list_rog)                         #найдем минимальное значение в листе
min_index_rog = list(grid_list_rog).index(min_value_train_rog)       #найдем индекс минимального значения в листе

# %%
print(f'Минимальное значение sMAPE на тренировочной выборке: {min_value_train_rog}')
# Out:
# Минимальное значение sMAPE на тренировочной выборке: 6.504714956913642

# %%
grid_1.cv_results_['params']
# Out:
# [{'max_depth': 5, 'n_estimators': 1},
#  {'max_depth': 5, 'n_estimators': 6},
#  {'max_depth': 5, 'n_estimators': 11},
#  {'max_depth': 5, 'n_estimators': 16},
#  {'max_depth': 5, 'n_estimators': 21},
#  {'max_depth': 5, 'n_estimators': 26},
#  {'max_depth': 10, 'n_estimators': 1},
#  {'max_depth': 10, 'n_estimators': 6},
#  {'max_depth': 10, 'n_estimators': 11},
#  {'max_depth': 10, 'n_estimators': 16},
#  {'max_depth': 10, 'n_estimators': 21},
#  {'max_depth': 10, 'n_estimators': 26},
#  {'max_depth': 15, 'n_estimators': 1},
#  {'max_depth': 15, 'n_estimators': 6},
#  {'max_depth': 15, 'n_estimators': 11},
#  {'max_depth': 15, 'n_estimators': 16},
#  {'max_depth': 15, 'n_estimators': 21},
#  {'max_depth': 15, 'n_estimators': 26},
#  {'max_depth': 20, 'n_estimators': 1},
#  {'max_depth': 20, 'n_estimators': 6},
#  {'max_depth': 20, 'n_estimators': 11},
#  {'max_depth': 20, 'n_estimators': 16},
#  {'max_depth': 20, 'n_estimators': 21},
#  {'max_depth': 20, 'n_estimators': 26},
# ...

# %%
grid_1.cv_results_['params'][min_index_rog] #лучшая комбинация параметров для минимального значения среднего sMAPE
# Out:
# {'max_depth': 25, 'n_estimators': 16}

# %% [markdown]
# #### Целевой признак - 'final.output.recovery'

# %%
# %%time

param_grid = [{'max_depth': list(range(5, 26, 5)),             #глубина дерева от 5 до 20 с шагом 5
               'n_estimators': list(range(1, 31, 5))}]         #деревьев в лесу от 1 до 25 с шагом 5

grid_2 = GridSearchCV(model_forest,
                      param_grid,
                      scoring=smape_scorer,
                      cv=5).fit(features_train, target_train_2)

grid_list_fin = grid_2.cv_results_['mean_test_score']    #найдем среднее значение нашей метрики на каждой итерации
# Out:
# CPU times: user 12min 51s, sys: 302 ms, total: 12min 51s
# Wall time: 12min 53s

# %%
display(grid_list_fin)       
print("Количество итераций:", len(grid_list_fin))
# Out:
# array([11.60164369,  9.94045007,  9.4846395 ,  9.31684437,  9.29081944,
#         9.2408037 , 13.03087089, 10.76106382, 10.3062428 ,  9.95675542,
#         9.84826408,  9.78418118, 15.07763841, 11.0147431 , 10.59521833,
#        10.35889144, 10.17584357, 10.07837439, 16.93196926, 11.547759  ,
#        10.79443964, 10.54104181, 10.30976806, 10.20361642, 16.69422658,
#        11.45903899, 10.64280683, 10.49738737, 10.31940266, 10.2305209 ])
# Количество итераций: 30

# %%
min_value_train_fin = min(grid_list_fin)                         #найдем минимальное значение в листе
min_index_fin = list(grid_list_fin).index(min_value_train_fin)   #найдем индекс минимального значения в листе

# %%
grid_2.cv_results_['params'][min_index_fin]
# Out:
# {'max_depth': 5, 'n_estimators': 26}

# %% [markdown]
# ### Лучшая модель и проверка её на тестовой выборке

# %%
# %%time

best_smape_result_1 = 10000

model_forest_1 = RandomForestRegressor(
            random_state=42,
            n_estimators=11,                   # модель с заданным количеством деревьев
            max_depth=5,                               # модель с заданной глубиной дерева
        )                                                             
        
model_forest_1.fit(features_train_rog, target_train_1)                    # обучение модели на тренировочной выборке для target_1
predictions_model_forest_1 = model_forest_1.predict(features_test_rog)    # предсказание модели на тестовой выборке для target_1
smape_results_1 = smape(target_test_1, predictions_model_forest_1)    # расчет smape по формуле 
       
if smape_results_1 < best_smape_result_1:
    best_smape_result_1 = smape_results_1                             # сохранение наилучшего значения метрики
# Out:
# CPU times: user 876 ms, sys: 0 ns, total: 876 ms
# Wall time: 890 ms

# %%
print("Параметры лучшей модели для 'rougher':")
print(model_forest_1)
print()
print("Лучший результат sMAPE на тестовой выборке для 'rougher':")
print(round(best_smape_result_1,4))
# Out:
# Параметры лучшей модели для 'rougher':
# RandomForestRegressor(max_depth=5, n_estimators=11, random_state=42)
#
# Лучший результат sMAPE на тестовой выборке для 'rougher':
# 8.3611

# %%
# %%time 

best_smape_result_2 = 10000

model_forest_2 = RandomForestRegressor(
            random_state=42,
            n_estimators=16,                   # модель с заданным количеством деревьев
            max_depth=5,                      # модель с заданной глубиной дерева
        )                                                             
        
model_forest_2.fit(features_train, target_train_2)                    # обучение модели на тренировочной выборке для target_1
predictions_model_forest_2 = model_forest_2.predict(features_test)    # предсказание модели на тестовой выборке для target_1
smape_results_2 = smape(target_test_2, predictions_model_forest_2)    # расчет smape по формуле 
       
if smape_results_2 < best_smape_result_2:
    best_smape_result_2 = smape_results_2                             # сохранение наилучшего значения метрики
# Out:
# CPU times: user 4.74 s, sys: 16 ms, total: 4.76 s
# Wall time: 4.79 s

# %%
print("Параметры лучшей модели для 'final':")
print(model_forest_2)
print()
print("Лучший результат sMAPE на тестовой выборке для 'final':")
print(round(best_smape_result_2,4))
# Out:
# Параметры лучшей модели для 'final':
# RandomForestRegressor(max_depth=5, n_estimators=16, random_state=42)
#
# Лучший результат sMAPE на тестовой выборке для 'final':
# 9.6111

# %%
total_smape_forest_test = total_smape(best_smape_result_1,best_smape_result_2)

print(f'Итоговое значнение sMAPE "случайный лес" для тестовой выборки: {total_smape_forest_test}')
# Out:
# Итоговое значнение sMAPE "случайный лес" для тестовой выборки: 9.2986

# %% [markdown]
# ### Проверка тестовых данных моделью "Dummy"

# %%
from sklearn.dummy import DummyRegressor                  #загрузим модуль Dummy, где на предсказания не влияют входные признаки

dummy_regr_1 = DummyRegressor(strategy="mean")            #всегда предсказываем среднее значение выборки для target_1
dummy_regr_2 = DummyRegressor(strategy="mean")            #всегда предсказываем среднее значение выборки для target_2

dummy_regr_1.fit(features_train_rog, target_train_1)      #"обучаем" модель на target_1
dummy_regr_2.fit(features_train_rog, target_train_2)      #"обучаем" модель на target_2

dummy_regr_pedict_1 = dummy_regr_1.predict(target_test_1) #предсказываем значения target_test_1
dummy_regr_pedict_2 = dummy_regr_2.predict(target_test_2) #предсказываем значения target_test_2

# %%
dummy_regr_smape_target_1 = smape(target_test_1,dummy_regr_pedict_1)
dummy_regr_smape_target_2 = smape(target_test_2,dummy_regr_pedict_2)

# %%
print(dummy_regr_smape_target_1)
print(dummy_regr_smape_target_2)
# Out:
# 9.069124389851533
# 10.078929505048979

# %%
total_smape_dummy_test = total_smape(dummy_regr_smape_target_1,dummy_regr_smape_target_2)

print(f'Итоговое значнение sMAPE "Dummy" для тестовой выборки: {total_smape_dummy_test}')
# Out:
# Итоговое значнение sMAPE "Dummy" для тестовой выборки: 9.8265

# %% [markdown]
# ### Вывод ###

# %% [markdown]
# - Модель оценки обогащения золота на двух этапах 'rougher' и 'final' ошибается на 9.249% по метрике оценки качества sMAPE.
#     - По модулю отклонение фактического значения обогащения от прогнозируемого в процентном соотнощении составляет 9.3% для множества элементов выборки, что лучше показателя 9.8% "Dummy" модели, которая предсказывает среднее значение выборки.
#     - Показатель итогового значнения sMAPE "случайный лес" для тестовой выборки можно повысить, если увеличить количество перебираемых гипер-параметров и производительность вычислительной машины.
# - Можель с масштабированием данных показала результат хуже, откажемся от данного этапа.
# - Наилучшая модель для предсказания степени очистки:
#     - для 'rougher': RandomForestRegressor(max_depth=5, n_estimators=11, random_state=42)
#     - для 'final': RandomForestRegressor(max_depth=5, n_estimators=16, random_state=42)

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
